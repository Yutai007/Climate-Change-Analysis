# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
import plotly.express as px
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import time
import re
import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("GlobalLandTemperaturesByCountry.csv")

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577462 entries, 0 to 577461
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   dt                             577462 non-null  object
#  1   AverageTemperature             544811 non-null  float64
#  2   AverageTemperatureUncertainty  545550 non-null  float64
#  3   Country                        577462 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 13.2+ MB

# %%
countries = np.unique(df['Country'])

# %%
tempavg = []
for country in countries:
    tempavg.append(df[df['Country'] == country]['AverageTemperature'].mean())

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = tempavg,
        locationmode = 'country names',
        text = countries,
        colorscale = 'Jet',
        reversescale = False,
        marker = dict(
            line = dict(color = 'rgb(180,180,180)', width = 1)),
            colorbar = dict(
                autotick = False, 
                tickprefix = '',
                title = 'Avg Temp in °C')
            )
       ]

layout = dict(
    title = 'All Time Periods',
    geo = dict(
        showframe = True,
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 30,
                    lat = 15),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div>
#
#
#             <div id="f63c8b6f-c130-4b2d-b8b1-96037af33ef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f63c8b6f-c130-4b2d-b8b1-96037af33ef5")) {
#                     Plotly.newPlot(
#                         'f63c8b6f-c130-4b2d-b8b1-96037af33ef5',
# ...

# %%
years = []
for i in range(0, len(df["dt"])):
    yr = re.search(r'\d+', df["dt"][i]).group()
    years.append(yr)

# %%
tempavg_pre_1800 = []
for country in countries:
    tempavg_pre_1800.append(df[(df['Country'] == country) & (df['dt'] < "1800")]['AverageTemperature'].mean())

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = tempavg_pre_1800,
        locationmode = 'country names',
        text = countries,
        colorscale = 'Jet',
        reversescale = False,
        marker = dict(
            line = dict(color = 'rgb(180,180,180)', width = 1)),
            colorbar = dict(
                autotick = False, 
                tickprefix = '',
                title = 'Avg Temp in °C')
            )
       ]

layout = dict(
    title = '1750-1800',
    geo = dict(
        showframe = True,
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 30,
                    lat = 15),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div>
#
#
#             <div id="ac692ccf-403a-45f0-b329-c349f6ab5afb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ac692ccf-403a-45f0-b329-c349f6ab5afb")) {
#                     Plotly.newPlot(
#                         'ac692ccf-403a-45f0-b329-c349f6ab5afb',
# ...

# %%
tempavg_pre_1900 = []
for country in countries:
    tempavg_pre_1900.append(df[(df['Country'] == country) & (df['dt'] < "1900") & (df['dt'] > "1800")]['AverageTemperature'].mean())

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = tempavg_pre_1900,
        locationmode = 'country names',
        text = countries,
        colorscale = 'Jet',
        reversescale = False,
        marker = dict(
            line = dict(color = 'rgb(180,180,180)', width = 1)),
            colorbar = dict(
                autotick = False, 
                tickprefix = '',
                title = 'Avg Temp in °C')
            )
       ]

layout = dict(
    title = '1800-1900',
    geo = dict(
        showframe = True,
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 30,
                    lat = 15),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div>
#
#
#             <div id="d372fcf1-e184-40c2-9deb-b0cb325d799b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d372fcf1-e184-40c2-9deb-b0cb325d799b")) {
#                     Plotly.newPlot(
#                         'd372fcf1-e184-40c2-9deb-b0cb325d799b',
# ...

# %%
tempavg_pre_1970 = []
for country in countries:
    tempavg_pre_1970.append(df[(df['Country'] == country) & (df['dt'] < "1970") & (df['dt'] > "1900")]['AverageTemperature'].mean())

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = tempavg_pre_1970,
        locationmode = 'country names',
        text = countries,
        colorscale = 'Jet',
        reversescale = False,
        marker = dict(
            line = dict(color = 'rgb(180,180,180)', width = 1)),
            colorbar = dict(
                autotick = False, 
                tickprefix = '',
                title = 'Avg Temp in °C')
            )
       ]

layout = dict(
    title = '1900-1970',
    geo = dict(
        showframe = True,
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 30,
                    lat = 15),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div>
#
#
#             <div id="27792406-3ee8-4247-825d-6a06e1978259" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27792406-3ee8-4247-825d-6a06e1978259")) {
#                     Plotly.newPlot(
#                         '27792406-3ee8-4247-825d-6a06e1978259',
# ...

# %%
tempavg_modern = []
for country in countries:
    tempavg_modern.append(df[(df['Country'] == country) & (df['dt'] > "1970")]['AverageTemperature'].mean())

# %%
data = [ dict(
        type = 'choropleth',
        locations = countries,
        z = tempavg_modern,
        locationmode = 'country names',
        text = countries,
        colorscale = 'Jet',
        reversescale = False,
        marker = dict(
            line = dict(color = 'rgb(180,180,180)', width = 1)),
            colorbar = dict(
                autotick = False, 
                tickprefix = '',
                title = 'Avg Temp in °C')
            )
       ]

layout = dict(
    title = '1970-',
    geo = dict(
        showframe = True,
        projection = dict(
        type = 'orthographic',
            rotation = dict(
                    lon = 30,
                    lat = 15),
        ),
        lonaxis =  dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
            ),
        lataxis = dict(
                showgrid = True,
                gridcolor = 'rgb(211,211,211)'
                )
            ),
        )

fig = dict(data=data, layout=layout)
py.iplot(fig, validate=False, filename='worldmap')
# Out:
# <div>
#
#
#             <div id="6f544120-4330-480b-8c59-d994eb5fc57c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f544120-4330-480b-8c59-d994eb5fc57c")) {
#                     Plotly.newPlot(
#                         '6f544120-4330-480b-8c59-d994eb5fc57c',
# ...

# %%
df2 = pd.read_csv("GTCSV.csv")

# %%
years = np.unique(df2['dt'].apply(lambda x: x[:4]))

# %%
temp_over_time_df2 = []
for yr in years:
    temp_over_time_df2.append(df2[df2['dt'].apply(lambda x: x[:4]) == yr]['LandAverageTemperature'].mean())

# %%
data = go.Scatter(
    x = years, 
    y = temp_over_time_df2,
    name='Global Temp',
    line=dict(
        color='rgb(23, 240, 19)',
    )
)

# %%
layout = go.Layout(
    xaxis=dict(title='year'),
    yaxis=dict(title='Average Temperature'),
    title='Average Land Temperature Over Time'
)

# %%
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="5940876b-095d-4f2e-97df-5c39adca74c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5940876b-095d-4f2e-97df-5c39adca74c0")) {
#                     Plotly.newPlot(
#                         '5940876b-095d-4f2e-97df-5c39adca74c0',
# ...

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
temp_over_time = []
for yr in years:
    temp_over_time.append(df[df['dt'].apply(lambda x: x[:4]) == yr]['AverageTemperature'].mean())

# %%
USA_tot = []
for yr in years:
    USA_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "United States")]['AverageTemperature'].mean())

# %%
Global_Data = go.Scatter(
    x = years, 
    y = temp_over_time,
    name='Global Temp',
    line=dict(
        color='rgb(23, 240, 19)',
    )
)

# %%
USA_Data = go.Scatter(
    x = years, 
    y = USA_tot,
    name='USA Temp',
    line=dict(
        color='rgb(0, 40, 104)',
    )
)

# %%
Brazil_tot = []
for yr in years:
    Brazil_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "Brazil")]['AverageTemperature'].mean())

# %%
Brazil_Data = go.Scatter(
    x = years, 
    y = Brazil_tot,
    name='Brazil Temp',
    line=dict(
        color='rgb(0, 156, 59)',
    )
)

# %%
China_tot = []
for yr in years:
    China_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "China")]['AverageTemperature'].mean())

# %%
China_Data = go.Scatter(
    x = years, 
    y = China_tot,
    name='China Temp',
    line=dict(
        color='rgb(255,255,0)',
    )
)

# %%
Australia_tot = []
for yr in years:
    Australia_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "Australia")]['AverageTemperature'].mean())

# %%
Australia_Data = go.Scatter(
    x = years, 
    y = Australia_tot,
    name='Australia Temp',
    line=dict(
        color='rgb(173, 216, 230)',
    )
)

# %%
Nigeria_tot = []
for yr in years:
    Nigeria_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "Nigeria")]['AverageTemperature'].mean())

# %%
Nigeria_Data = go.Scatter(
    x = years, 
    y = Nigeria_tot,
    name='Nigeria Temp',
    line=dict(
        color='rgb(255,255,255)',
    )
)

# %%
France_tot = []
for yr in years:
    France_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "France")]['AverageTemperature'].mean())

# %%
France_Data = go.Scatter(
    x = years, 
    y = France_tot,
    name='France Temp',
    line=dict(
        color='rgb(255,0,255)',
    )
)

# %%
Russia_tot = []
for yr in years:
    Russia_tot.append(df[(df['dt'].apply(lambda x: x[:4]) == yr) & (df['Country'] == "Russia")]['AverageTemperature'].mean())

# %%
Russia_Data = go.Scatter(
    x = years, 
    y = Russia_tot,
    name='Russia Temp',
    line=dict(
        color='rgb(255,0,0)',
    )
)

# %%
data = [Global_Data, USA_Data, Brazil_Data, China_Data, Australia_Data, Nigeria_Data, France_Data, Russia_Data]

# %%
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="79d42a32-0d5c-4aac-8dbb-a3264e9e467f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79d42a32-0d5c-4aac-8dbb-a3264e9e467f")) {
#                     Plotly.newPlot(
#                         '79d42a32-0d5c-4aac-8dbb-a3264e9e467f',
# ...

# %%
list3 = [years,temp_over_time_df2]

# %%
list3_t = np.array(list3).T.tolist()

# %%
df3 = pd.DataFrame(list3_t, columns =['Time', 'Temperature'])

# %%
df3.head()
# Out:
#    Time  Temperature
# 0  1750     8.719364
# 1  1751     7.976143
# 2  1752     5.779833
# 3  1753     8.388083
# 4  1754     8.469333

# %%
sns.jointplot(data=df3, x="Time", y="Temperature")

# %%
df2.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
import datetime

# %%
a = "1750-05-01"

# %%
datee = datetime.datetime.strptime(a, "%Y-%m-%d")

# %%
datee.month
# Out:
# 5

# %%
print(int(a[5:7]))
# Out:
# 5

# %%
print(int(a[0:4]))
# Out:
# 1750

# %%
Year_df2 = []
for i in range(0, len(df2["dt"])):
    Year_df2.append(int(df2['dt'][i][0:4]))
df2["Year"] = Year_df2

# %%
Month_df2 = []
for i in range(0, len(df2["dt"])):
    Month_df2.append(int(df2['dt'][i][5:7]))
df2["Month"] = Month_df2

# %%
palette = ['red','green','orange','cyan','yellow','blue','magenta','brown','maroon','navy','grey','purple']

# %%
sns.jointplot(data=df2, x="Year", y="LandAverageTemperature", hue="Month", palette=palette)

# %%
from sklearn.model_selection import train_test_split

# %%
df2.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
y = df4['LandAverageTemperature']

# %%
X = df4[['Year','Month']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=99)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
df4 = df2.dropna(subset=['LandAverageTemperature'])

# %%
print(lm.coef_)
# Out:
# [0.00448605 0.32522538]

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Prediction')
# Out:
# Text(0, 0.5, 'Prediction')

# %%
print(df4['LandAverageTemperature'].corr(df4['Year']))
# Out:
# 0.08144851570057911

# %%
from sklearn import metrics

# %%
coef = pd.DataFrame(lm.coef_,X.columns)
coef.columns = ['Coeffecient']
coef
# Out:
#        Coeffecient
# Year      0.004486
# Month     0.325225

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,predictions)
# Out:
# 17.665221034149717

# %%
df4.drop(df4.index[(df4['Month'] != 1)],axis=0,inplace=True)

# %%
df4.head()
# Out:
#             dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0   1750-01-01                   3.034                              3.574
# 12  1751-01-01                   2.495                              3.469
# 24  1752-01-01                   0.348                              3.789
# 36  1753-01-01                   2.039                              3.478
# 48  1754-01-01                   1.574                              5.020
#
#     LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                  NaN                            NaN                 NaN
# 12                 NaN                            NaN                 NaN
# 24                 NaN                            NaN                 NaN
# 36                 NaN                            NaN                 NaN
# 48                 NaN                            NaN                 NaN
#
#     LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
sns.jointplot(data=df4, x="Year", y="LandAverageTemperature")

# %%
df4.drop(df4.index[(df4['Year'] < 1900)],axis=0,inplace=True)

# %%
sns.jointplot(data=df4, x="Year", y="LandAverageTemperature")

# %%
print(df4['LandAverageTemperature'].corr(df4['Year']))
# Out:
# 0.6885057518182995

# %%
df5 = df2.dropna(subset=['LandAverageTemperature'])

# %%
print(df5['LandAverageTemperature'].corr(df5['Year']))
# Out:
# 0.08144851570057911

# %%
sns.jointplot(data=df5, x="Year", y="LandAverageTemperature")

# %%
df5.drop(df5.index[(df5['Month'] != 6)],axis=0,inplace=True)

# %%
df5.drop(df5.index[(df5['Year'] < 1900)],axis=0,inplace=True)

# %%
sns.jointplot(data=df5, x="Year", y="LandAverageTemperature")

# %%
print(df5['LandAverageTemperature'].corr(df5['Year']))
# Out:
# 0.7939649315641601
